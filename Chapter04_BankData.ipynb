# %% [markdown]
# Input variables:
#
# **bank client data:**
# 1 - age (numeric)
# 2 - job : type of job (categorical: 'admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
# 3 - marital : marital status (categorical: 'divorced','married','single','unknown'; note: 'divorced' means divorced or widowed)
# 4 - education (categorical: 'basic.4y','basic.6y','basic.9y','high.school','illiterate','professional.course','university.degree','unknown')
# 5 - default: has credit in default? (categorical: 'no','yes','unknown')
# 6 - housing: has housing loan? (categorical: 'no','yes','unknown')
# 7 - loan: has personal loan? (categorical: 'no','yes','unknown')
#
# **related with the last contact of the current campaign:**
# 8 - contact: contact communication type (categorical: 'cellular','telephone')
# 9 - month: last contact month of year (categorical: 'jan', 'feb', 'mar', ..., 'nov', 'dec')
# 10 - day_of_week: last contact day of the week (categorical: 'mon','tue','wed','thu','fri')
# 11 - duration: last contact duration, in seconds (numeric). **Important note:** this attribute highly affects the output target (e.g., if duration=0 then y='no').
# Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
#
# **other attributes:**
# 12 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
# 13 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
# 14 - previous: number of contacts performed before this campaign and for this client (numeric)
# 15 - poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')
#
# **social and economic context attributes**
# 16 - emp.var.rate: employment variation rate - quarterly indicator (numeric)
# 17 - cons.price.idx: consumer price index - monthly indicator (numeric)
# 18 - cons.conf.idx: consumer confidence index - monthly indicator (numeric)
# 19 - euribor3m: euribor 3 month rate - daily indicator (numeric)
# 20 - nr.employed: number of employees - quarterly indicator (numeric)
#
# **Output variable (desired target):**
# 21 - y - has the client subscribed a term deposit? (binary: 'yes','no')

# %%
import pandas as pd

df_raw = pd.read_csv("bank.csv", delimiter=";")
df = df_raw
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %% [markdown]
# Our target is `y`, which is "yes" when the client agreed to sign the contract with the bank, "no" otherwise.
# Goal:
# * Find what makes people say yes
# * Create a predictor that, given a client situation, will predict weither the client will agree to the contract or not.
#
# Read the first cell of this Notebook where variables are described.
# It is said that `duration` should only be used for benchmark purpose, so we need to discard it

# %%
df = df.drop('duration', axis=1)
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct         1     -1         0  unknown  no
# 1     cellular   11   may         1    339         4  failure  no
# 2     cellular   16   apr         1    330         1  failure  no
# 3      unknown    3   jun         4     -1         0  unknown  no
# 4      unknown    5   may         1     -1         0  unknown  no
# ...        ...  ...   ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul         5     -1         0  unknown  no
# 4517   unknown    9   may         1     -1         0  unknown  no
# 4518  cellular   19   aug        11     -1         0  unknown  no
# 4519  cellular    6   feb         4    211         3    other  no
# 4520  cellular    3   apr         2    249         7    other  no
#
# [4521 rows x 16 columns]

# %% [markdown]
# # Using LabelEncoder on columns that needs it

# %%
df.describe()
# Out:
#                age       balance          day     campaign        pdays  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284     2.793630    39.766645
# std      10.576211   3009.638142     8.247667     3.109807   100.121124
# min      19.000000  -3313.000000     1.000000     1.000000    -1.000000
# 25%      33.000000     69.000000     9.000000     1.000000    -1.000000
# 50%      39.000000    444.000000    16.000000     2.000000    -1.000000
# 75%      49.000000   1480.000000    21.000000     3.000000    -1.000000
# max      87.000000  71188.000000    31.000000    50.000000   871.000000
#
#           previous
# count  4521.000000
# mean      0.542579
# std       1.693562
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max      25.000000

# %% [markdown]
# Only the columns with numerical data were processed by `df.describe()`. Let's use it to get the list of the columns that needs processing.

# %%
numerical_columns = set(df.describe().columns)
numerical_columns
# Out:
# {'age', 'balance', 'campaign', 'day', 'pdays', 'previous'}

# %%
columns_to_encode = list(set(df.columns) - numerical_columns)
columns_to_encode
# Out:
# ['education',
#  'contact',
#  'month',
#  'job',
#  'default',
#  'loan',
#  'poutcome',
#  'y',
#  'housing',
#  'marital']

# %%
from sklearn.preprocessing import LabelEncoder

# We keep each column encoder in a list in order to inverse_transform later if we need it.
columns_encoders = []

for col in columns_to_encode:
    tmp_encoder = LabelEncoder()
    tmp_encoder.fit(df[col])
    df[col] = tmp_encoder.transform(df[col])
    columns_encoders.append(tmp_encoder)

# %%
for column, encoder in zip(columns_to_encode, columns_encoders):
    print(column, encoder.classes_)
# Out:
# education ['primary' 'secondary' 'tertiary' 'unknown']
# contact ['cellular' 'telephone' 'unknown']
# month ['apr' 'aug' 'dec' 'feb' 'jan' 'jul' 'jun' 'mar' 'may' 'nov' 'oct' 'sep']
# job ['admin.' 'blue-collar' 'entrepreneur' 'housemaid' 'management' 'retired'
#  'self-employed' 'services' 'student' 'technician' 'unemployed' 'unknown']
# default ['no' 'yes']
# loan ['no' 'yes']
# poutcome ['failure' 'other' 'success' 'unknown']
# y ['no' 'yes']
# housing ['no' 'yes']
# marital ['divorced' 'married' 'single']

# %% [markdown]
# We "automatized" the process of labelling but it's important to take a look at the result.
#
# Here, it looks like the different values are okay.
#
# But in Titanic project, it would not be ok to have a label for each Cabin, it would be too much values and thus noise.

# %% [markdown]
# # Analyse correlations

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_27bfb_row0_col0, #T_27bfb_row1_col1, #T_27bfb_row2_col2, #T_27bfb_row3_col3, #T_27bfb_row4_col4, #T_27bfb_row5_col5, #T_27bfb_row6_col6, #T_27bfb_row7_col7, #T_27bfb_row8_col8, #T_27bfb_row9_col9, #T_27bfb_row10_col10, #T_27bfb_row11_col11, #T_27bfb_row12_col12, #T_27bfb_row13_col13, #T_27bfb_row14_col14, #T_27bfb_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_27bfb_row0_col1, #T_27bfb_row1_col11, #T_27bfb_row2_col9, #T_27bfb_row3_col11, #T_27bfb_row6_col11 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_27bfb_row0_col2, #T_27bfb_row0_col3, #T_27bfb_row0_col6, #T_27bfb_row2_col0, #T_27bfb_row4_col5, #T_27bfb_row5_col4, #T_27bfb_row5_col7, #T_27bfb_row6_col1, #T_27bfb_row7_col5, #T_27bfb_row8_col15, #T_27bfb_row10_col11, #T_27bfb_row11_col10, #T_27bfb_row12_col8, #T_27bfb_row12_col9, #T_27bfb_row12_col14, #T_27bfb_row14_col12, #T_27bfb_row14_col13, #T_27bfb_row15_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_27bfb_row0_col4, #T_27bfb_row8_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_27bfb_row0_col5, #T_27bfb_row15_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_27bfb_row0_col7, #T_27bfb_row1_col6, #T_27bfb_row3_col4, #T_27bfb_row6_col9, #T_27bfb_row7_col15, #T_27bfb_row8_col5, #T_27bfb_row8_col9, #T_27bfb_row9_col5, #T_27bfb_row11_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_27bfb_row0_col8, #T_27bfb_row12_col15 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_27bfb_row0_col9, #T_27bfb_row15_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_27bfb_row0_col10, #T_27bfb_row7_col3, #T_27bfb_row8_col7, #T_27bfb_row9_col7, #T_27bfb_row15_col10 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_27bfb_row0_col11, #T_27bfb_row2_col5, #T_27bfb_row12_col1, #T_27bfb_row13_col5, #T_27bfb_row14_col7 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_27bfb_row0_col12, #T_27bfb_row0_col14, #T_27bfb_row15_col13 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_27bfb_row0_col13 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_27bfb_row0_col15, #T_27bfb_row5_col3, #T_27bfb_row11_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_27bfb_row1_col0, #T_27bfb_row1_col3, #T_27bfb_row4_col2, #T_27bfb_row12_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_27bfb_row1_col2, #T_27bfb_row8_col6 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_27bfb_row1_col4, #T_27bfb_row4_col9, #T_27bfb_row6_col4, #T_27bfb_row8_col4, #T_27bfb_row10_col9, #T_27bfb_row14_col10 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_27bfb_row1_col5, #T_27bfb_row7_col1, #T_27bfb_row12_col5, #T_27bfb_row15_col6, #T_27bfb_row15_col9 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_27bfb_row1_col7, #T_27bfb_row6_col3, #T_27bfb_row10_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T
col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_27bfb_row7_col2, #T_27bfb_row9_col11 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_27bfb_row7_col6 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_27bfb_row7_col11 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_27bfb_row7_col13 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_27bfb_row7_col14, #T_27bfb_row10_col12 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_27bfb_row8_col0, #T_27bfb_row12_col2, #T_27bfb_row15_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_27bfb_row8_col2 {
#   backgr

# %% [markdown]
# Let's take a specific look at our target `y`
#
# Our goal is to find the values that are the farthest from 0

# %%
df.corr()['y'].apply(lambda x: x if x > 0 else -x).sort_values(ascending=False)
# Out:
# y            1.000000
# contact      0.133595
# previous     0.116714
# housing      0.104683
# pdays        0.104087
# poutcome     0.082632
# loan         0.070517
# campaign     0.061147
# age          0.045092
# education    0.042987
# month        0.040933
# job          0.027401
# balance      0.017905
# marital      0.015042
# day          0.011244
# default      0.001303
# Name: y, dtype: float64

# %%
# Plot the values (without y)
df.corr()['y'].apply(lambda x: x if x > 0 else -x).sort_values(ascending=False)[1:].plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# It looks like the most important features (in order to predict the target) are:
# * Contact
# * Previous
# * Housing
# * PDays
# * Poutcome
# * Loan
# * Campaign
#
# Let's visualize how they help determine the target

# %% [markdown]
# ### Contact

# %%
# Method 1 : use the encoders to inverse_transform values

def df_inverse_transform(columns):
    new_df = pd.DataFrame()
    for col in columns:
        index = columns_to_encode.index(col)
        encoder = columns_encoders[index]
        values = encoder.inverse_transform(df[col])
        new_df[col] = values
    return new_df.reset_index()
        
tmp = df_inverse_transform(['contact', 'y'])
tmp
# Out:
#       index   contact   y
# 0         0  cellular  no
# 1         1  cellular  no
# 2         2  cellular  no
# 3         3   unknown  no
# 4         4   unknown  no
# ...     ...       ...  ..
# 4516   4516  cellular  no
# 4517   4517   unknown  no
# 4518   4518  cellular  no
# 4519   4519  cellular  no
# 4520   4520  cellular  no
#
# [4521 rows x 3 columns]

# %%
tmp.groupby(['contact', 'y']).count()
# Out:
#                index
# contact   y
# cellular  no    2480
#           yes    416
# telephone no     257
#           yes     44
# unknown   no    1263
#           yes     61

# %%
print(416/(2480+416)*100)
print(44/(44+257)*100)
print(61/(61+1263)*100)
# Out:
# 14.3646408839779
# 14.61794019933555
# 4.607250755287009

# %% [markdown]
# We see that the client has more chance of saying 'no' when the contact is unknown

# %% [markdown]
# ### Previous
#
# number of contacts performed before this campaign and for this client

# %%
# Method2: Just keep the DataFrame untouched from the processed DataFrame

df_raw[['previous', 'y']].reset_index().groupby(['previous', 'y']).count()
# Out:
#               index
# previous y
# 0        no    3368
#          yes    337
# 1        no     235
#          yes     51
# 2        no     143
#          yes     50
# 3        no      91
#          yes     22
# 4        no      53
#          yes     25
# 5        no      34
#          yes     13
# 6        no      16
#          yes      9
# 7        no      19
#          yes      3
# 8        no      15
#          yes      3
# 9        no       7
#          yes      3
# 10       no       2
#          yes      2
# 11       no       3
# 12       no       4
#          yes      1
# 13       no       1
# 14       yes      2
# 15       no       1
# 17       no       1
# 18       no       1
# 19       no       1
# 20       no       1
# 22       no       1
# 23       no       1
# 24       no       1
# 25       no       1

# %%
# Here, we use a custom function to compute the %age of total yes/no contained in each combination

df_raw[['previous', 'y']].reset_index().groupby(['previous', 'y']).apply(lambda x: 
                                                                         round(len(x['index']) / len(df_raw) * 100, 2))
# Out:
# previous  y
# 0         no     74.50
#           yes     7.45
# 1         no      5.20
#           yes     1.13
# 2         no      3.16
#           yes     1.11
# 3         no      2.01
#           yes     0.49
# 4         no      1.17
#           yes     0.55
# 5         no      0.75
#           yes     0.29
# 6         no      0.35
#           yes     0.20
# 7         no      0.42
#           yes     0.07
# 8         no      0.33
#           yes     0.07
# 9         no      0.15
#           yes     0.07
# 10        no      0.04
#           yes     0.04
# 11        no      0.07
# 12        no      0.09
#           yes     0.02
# 13        no      0.02
# 14        yes     0.04
# 15        no      0.02
# 17        no      0.02
# 18        no      0.02
# 19        no      0.02
# 20        no      0.02
# 22        no      0.02
# 23        no      0.02
# 24        no      0.02
# 25        no      0.02
# dtype: float64

# %% [markdown]
# We see that the client has more chance of saying yes if they have been contacted only once.

# %% [markdown]
# ### Housing
#
# has housing loan?

# %%
df_raw[['housing', 'y']].reset_index().groupby(['housing', 'y']).count()
# Out:
#              index
# housing y
# no      no    1661
#         yes    301
# yes     no    2339
#         yes    220

# %%
print(301/(301+1661)*100)
print(220/(2339+220)*100)
# Out:
# 15.341488277268095
# 8.597108245408362

# %% [markdown]
# Here, we see there is more chance of saying 'yes' if the client does not have an housing loan.

# %% [markdown]
# ### pdays
#
# number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)

# %%
x = df_raw[['pdays', 'y']].reset_index().groupby(['pdays', 'y']).count().reset_index()
x.head(15)
# Out:
#     pdays    y  index
# 0      -1   no   3368
# 1      -1  yes    337
# 2       1  yes      2
# 3       2   no      7
# 4       3   no      1
# 5       5   no      1
# 6       7   no      3
# 7      28   no      1
# 8      38  yes      1
# 9      56  yes      1
# 10     57  yes      1
# 11     58   no      1
# 12     59   no      1
# 13     60  yes      1
# 14     61   no      1

# %% [markdown]
# # Train
#
# * Contact
# * Previous
# * Housing
# * PDays
# * Poutcome
# * Loan
# * Campaign

# %%
features = ['contact', 'previous', 'housing', 'pdays', 'poutcome', 'loan', 'campaign']
X = df[features]
X.shape
# Out:
# (4521, 7)

# %%
y = df['y']
y.shape
# Out:
# (4521,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
def get_best_clf(classifiers, print_best=True):
    top_clf = []
    for clf in classifiers:
        clf = clf.fit(X_train, y_train)
        acc = accuracy_score(y_test, clf.predict(X_test))
        top_clf.append((acc, clf))  ## add the tuple (accuracy, algorithm) in the list

    top_clf.sort(reverse=True)  # trie en ordre décroissant
    if print_best:
        [print(clf) for clf in top_clf]
    return top_clf[0][1]

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC
from sklearn.cluster import KMeans

from sklearn.metrics import accuracy_score

classifiers = [
    MLPClassifier(max_iter=300),
    KMeans(n_clusters=2),
    DecisionTreeClassifier(),
    SVC()
]

best_clf = get_best_clf(classifiers)
